# %%
import pandas as pd
import numpy as np
from collections import Counter
import re
import spacy
import nltk
from nltk.corpus import words, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import contractions
from tqdm import tqdm
tqdm.pandas()

# %%
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('stopwords', quiet=True)
# Out:
# True

# %%
ENGLISH_WORDS = set(w.lower() for w in words.words())
STOP_WORDS = set(w for w in stopwords.words('english'))

# %% [markdown]
# # Load & Inspect Data

# %%
DATA_PATH = 'data/fakeNewsClassificationData.csv'

# %%
raw_data = pd.read_csv(DATA_PATH)

# %%
display(raw_data.head())
# Out:
#                                                title              author  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
print("Size of dataset:", raw_data.shape[0])
# Out:
# Size of dataset: 20800

# %% [markdown]
# ## Sample Record

# %%
for c in raw_data.columns:
    print(c, ":", raw_data.loc[5][c])
    print()
# Out:
# title : Jackie Mason: Hollywood Would Love Trump if He Bombed North Korea over Lack of Trans Bathrooms (Exclusive Video) - Breitbart
#
# author : Daniel Nussbaum
#
# text : In these trying times, Jackie Mason is the Voice of Reason. [In this week’s exclusive clip for Breitbart News, Jackie discusses the looming threat of North Korea, and explains how President Donald Trump could win the support of the Hollywood left if the U. S. needs to strike first.  “If he decides to bomb them, the whole country will be behind him, because everybody will realize he had no choice and that was the only thing to do,” Jackie says. “Except the Hollywood left. They’ll get nauseous. ” “[Trump] could win the left over, they’ll fall in love with him in a minute. If he bombed them for a better reason,” Jackie explains. “Like if they have no transgender toilets. ” Jackie also says it’s no surprise that Hollywood celebrities didn’t support Trump’s strike on a Syrian airfield this month. “They were infuriated,” he says. “Because it might only save lives. That doesn’t mean anything to them. If it only saved the environment, or climate change! They’d be the happiest people in the world. ” Still, Jackie says he’s got nothing against Hollywood celebs. They’ve got a tough life in this country. Watch Jackie’s latest clip above.   Follow Daniel Nussbaum on Twitter: @dznussbaum
#
# label : 0

# %% [markdown]
# ## Handle Missing Data

# %%
print("Count of records with missing data:")
print(raw_data.isna().sum())
# Out:
# Count of records with missing data:
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
prepped_data = raw_data.dropna(subset=['text'])
print(prepped_data.isna().sum())
# Out:
# title      558
# author    1918
# text         0
# label        0
# dtype: int64

# %% [markdown]
# ## Handle Duplicate Data

# %%
prepped_data.duplicated().sum()
# Out:
# 109

# %%
prepped_data = prepped_data.drop_duplicates()

# %%
prepped_data.shape
# Out:
# (20652, 4)

# %% [markdown]
# ## Check for Meta-data Leakage

# %%
# for idx in list(prepped_data['title'][prepped_data['title'].isna()].index):
#     print(prepped_data.loc[idx])
#     print()

# %%
prepped_data['label'][prepped_data['title'].isna()].unique()
# Out:
# array([1], dtype=int64)

# %% [markdown]
# * It appears that all the records with missing title happen to be fake news. So, the absence of a title could be a characterisitic of fake news.

# %%
c_fake = 0
c_real = 0
for i,(author,title,label) in enumerate(prepped_data[['author','title','label']].values):
    if 'anonymous' in str(title).lower():
        # print(author, "->", title, "->", label)
        if label==1:
            c_fake += 1
        else:
            c_real += 1

# %%
c_fake, c_real
# Out:
# (27, 3)

# %% [markdown]
# * Majority of the records in which the title contained the word 'anonymous', the news turned out to be fake. However, the number is very small compared to the total number of records.

# %%
c_fake = 0
c_real = 0
for i,(author,title,label) in enumerate(prepped_data[['author','title','label']].values):
    if re.match(r'\bno\b|\bnone\b|\bnil\b', str(title).lower()):
        # print(author, "->", title, "->", label)
        if label==1:
            c_fake += 1
        else:
            c_real += 1

# %%
c_fake, c_real
# Out:
# (21, 21)

# %%
prepped_data['label'][prepped_data['author'].isna()].value_counts()
# Out:
# label
# 1    1867
# 0      26
# Name: count, dtype: int64

# %% [markdown]
# * Majority of the records with missing author name are fake, while a small number of them are real too. So it cannot be a definitive trait.

# %%
idxs = []
for i,author in enumerate(prepped_data['author'].values):
    if 'anonymous' in str(author).lower() or  re.match(r'\bno\b|\bnone\b|\bnil\b', str(author).lower()):
        print(author)
        idxs.append(i)
# Out:
# Anonymous Coward (UID 12781064)
# Anonymous
# Anonymous
# Anonymous Coward (UID 11897093)
# Anonymous
# Anonymous Coward (UID 73268493)
# Anonymous
# Anonymous
# Anonymous Coward (UID 19747754)
# Anonymous
# Anonymous Coward (UID 26968733)
# No Author
# Anonymous Coward (UID 47910020)
# Anonymous Coward (UID 73270245)
# Anonymous Coward (UID 73268493)
# Anonymous
# Anonymous
# No Author
# Anonymous
# Anonymous Coward (UID 73270427)
# No Author
# Anonymous: World War 3 Is On The Horizon (In 2016) – Collective Evolution
# No Author
# Anonymous
# Anonymous
# Anonymous
# No Author
# Anonymous Coward (UID 58307359)
# Anonymous
# Anonymous Coward (UID 73270620)
# World War 3 News 2016: Anonymous Declares WW3 'on the Horizon'
# Anonymous
# Anonymous
# Anonymous Activist
# Anonymous
# Anonymous Coward (UID 18807137)
# Anonymous Coward (UID 73271258)
# Anonymous
# Anonymous
# Anonymous Coward (UID 73270906)
# Anonymous
# No Author
# Anonymous
# No Author
# Anonymous
# No Author
# Anonymous
# Anonymous: There Is No One Way To Live On This Planet, But We Can Be Harmonious – Collective Evolution
# Anonymous
# Anonymous
# No Author
# Anonymous
# Anonymous Coward (UID 68756703)
# No Author
# Anonymous Coward (UID 69290995)
# Anonymous
# Anonymous
# Anonymous
# Anonymous Coward (UID 72242221)
# No Author
# Anonymous Coward (UID 73271054)
# Anonymous Coward (UID 73110918)
# Anonymous
# Anonymous
# Anonymous Coward (UID 58059507)
# No Author
# No Author
# No Author
# Anonymous Coward (UID 72417024)
# Anonymous Coward (UID 46844538)
# Anonymous Coward (UID 73266834)
# Anonymous Coward (UID 73268261)
# Anonymous Coward (UID 69826920)
# Anonymous Coward (UID 73271485)
# Anonymous Coward (UID 64345242)
# Anonymous Coward (UID 72417024)
# No Author
# Anonymous Coward (UID 73268493)
# No Author
# No Author
# Anonymous Coward (UID 1786283)
# Anonymous Coward (UID 47402853)
# Anonymous Coward (UID 73226313)
# Anonymous Coward (UID 73271172)
# Anonymous Coward (UID 68881719)
# Anonymous
# Anonymous
# Anonymous Coward (UID 73270427)
# No Author
# No Author
# Anonymous Coward (UID 73271104)
# Anonymous
# No Author
# No Author
# Anonymous
# Anonymous Coward (UID 58059507)
# Anonymous Coward (UID 73269813)
# Anonymous Coward (UID 118243)
# Anonymous
# Anonymous Coward (UID 73270245)
# Anonymous Coward (UID 73237446)
# Anonymous
# Anonymous Coward (UID 70076674)
# Anonymous
# Anonymous Coward (UID 73270427)
# Anonymous
# Anonymous
# Anonymous Coward (UID 58059507)
# Anonymous Coward (UID 26968733)
# Anonymous Coward (UID 69608020)
# Anonymous Activist
# Anonymous
# Anonymous Coward (UID 63478933)
# Anonymous Coward (UID 73135225)
# Anonymous Coward (UID 67204360)
# Anonymous Coward (UID 72071746)

# %%
print(len(idxs))
# Out:
# 116

# %%
prepped_data.iloc[idxs]['label'].unique()
# Out:
# array([1], dtype=int64)

# %% [markdown]
# * Other than explicitly missing values for author column, there are records with names that contain the word 'anonymous' and 'no author', these have been found to be all fake.

# %%
def metadata_stats(df, col):
    # col becomes index
    stats = df.groupby(col).agg(
        total=('text', 'size'),
        fakeness=('label', 'mean'))
    # changing col back to a column and sorting groupby table
    stats = stats.reset_index().sort_values('total', ascending=False)
    return stats

# %%
author_stats = metadata_stats(prepped_data, 'author')

# %%
author_stats.head(20)
# Out:
#                    author  total  fakeness
# 2944              Pam Key    243  0.004115
# 3929                admin    192  1.000000
# 1762        Jerome Hudson    166  0.000000
# 724      Charlie Spiering    141  0.000000
# 1857         John Hayward    140  0.000000
# 2090  Katherine Rodriguez    124  0.000000
# 3845   Warner Todd Huston    122  0.000000
# 1520         Ian Hanchett    119  0.000000
# 577        Breitbart News    118  0.000000
# 914       Daniel Nussbaum    112  0.000000
# 40            AWR Hawkins    107  0.000000
# 1711            Jeff Poor    107  0.000000
# 1836       Joel B. Pollak    106  0.000000
# 3750          Trent Baker    102  0.000000
# 576      Breitbart London     97  0.000000
# 549             Bob Price     93  0.000000
# 480               Ben Kew     90  0.000000
# 717          Charlie Nash     88  0.000000
# 2939             Pakalert     85  1.000000
# 1111          Eddy Lavine     85  1.000000

# %%
author_leakage = author_stats[(author_stats['total']>50) & ((author_stats['fakeness']<0.05) | (author_stats['fakeness']>0.95))]
print("Authors who are mostly found for one class:")
display(author_leakage)
# Out:
# Authors who are mostly found for one class:
#                                       author  total  fakeness
# 2944                                 Pam Key    243  0.004115
# 3929                                   admin    192  1.000000
# 1762                           Jerome Hudson    166  0.000000
# 724                         Charlie Spiering    141  0.000000
# 1857                            John Hayward    140  0.000000
# 2090                     Katherine Rodriguez    124  0.000000
# 3845                      Warner Todd Huston    122  0.000000
# 1520                            Ian Hanchett    119  0.000000
# 577                           Breitbart News    118  0.000000
# 914                          Daniel Nussbaum    112  0.000000
# 40                               AWR Hawkins    107  0.000000
# 1711                               Jeff Poor    107  0.000000
# 1836                          Joel B. Pollak    106  0.000000
# 3750                             Trent Baker    102  0.000000
# 576                         Breitbart London     97  0.000000
# 549                                Bob Price     93  0.000000
# 480                                  Ben Kew     90  0.000000
# 717                             Charlie Nash     88  0.000000
# 2939                                Pakalert     85  1.000000
# 1111                             Eddy Lavine     85  1.000000
# 3518                                Starkman     84  1.000000
# 140                              Alex Ansary     82  1.000000
# 1376                                 Gillian     82  1.000000
# 1112                                  Editor     81  1.000000
# 2315                             Lucas Nolan     80  0.000000
# 4080   noreply@blogger.com (Alexander Light)     80  1.000000
# 944                              Dave Hodges     77  1.000000
# 575                      Breitbart Jerusalem     75  0.000000
# 1513                                     IWB     75  1.000000
# 1841                             John Binder     75  0.000000
# 3646                The European Union Times     74  1.000000
# 457                           BareNakedIslam     74  1.000000
# 55                             Activist Post     72  1.000000
# 1110                                EdJenner     69  1.000000
# 3643                                 The Doc     69  1.000000
# 1475                             Henry Wolff     67  1.000000
# 3025                             Penny Starr     67  0.000000
# 1547                              Iron Sheik     66  1.000000
# 2336                               Mac Slavo     66  1.000000
# 2047                         Kaitlyn Stegall     65  1.000000
# 1290                          Frances Martel     64  0.000000
# 3729                            Tom Ciccotta     64  0.000000
# 1682                              Jason Ditz     64  1.000000
# 4081     noreply@blogger.com (Der Postillon)     64  1.000000
# 1091                         Dr. Susan Berry     63  0.000000
# 991                           David Stockman     61  1.000000
# 1353                         Geoffrey Grider     61  1.000000
# 2163                         King World News     60  1.000000
# 1457                       Heather Callaghan     60  1.000000
# 4121                                  shorty     58  1.000000
# 826                       Consortiumnews.com     58  1.000000
# 3681               Thomas D. Williams, Ph.D.     57  0.000000
# 283    Andrea Kannapell and Sandra Stevenson     57  0.000000
# 2816                              Neil Munro     56  0.000000
# 3663                               The Saker     55  1.000000
# 896                                Dan Riehl     55  0.000000
# 45                               Aaron Klein     54  0.000000
# 1                                -NO AUTHOR-     53  1.000000
# 1046  Dikran Arakelian (noreply@blogger.com)     51  1.000000
# 4174                               wmw_admin     51  1.000000

# %% [markdown]
# * We can see that there are several authors corresponding to whom there are either 100% fake news or 100% real news. So, if the author data is fed to a classifier along with the text, the model may simply learn based on the author names instead of actual text and language features. Since, clearly, there is leakage from the author data, we will not be including it for further processing.

# %%
title_stats = metadata_stats(prepped_data, 'title')
title_stats.head(10)
# Out:
#                                                    title  total  fakeness
# 15400  The Dark Agenda Behind Globalism And Open Borders      5       1.0
# 6764   Get Ready For Civil Unrest: Survey Finds That ...      5       1.0
# 9609   Let’s Be Clear – A Vote For Warmonger Hillary ...      4       1.0
# 12658                            Public vs. Media on War      4       1.0
# 15490  The Fix Is In: NBC Affiliate Accidentally Post...      4       1.0
# 10400                        Michael Moore Owes Me $4.99      4       1.0
# 18350        What to Cook This Week - The New York Times      4       0.0
# 9469   Las imágenes libres de derechos más destacadas...      4       1.0
# 15833              The U.S. National Bird Is Now a Drone      4       1.0
# 18750  Will Barack Obama Delay Or Suspend The Electio...      4       1.0

# %%
title_stats.tail(10)
# Out:
#                                                    title  total  fakeness
# 6634   Gary Johnson Goes Zombie, Tries to Bite Reporters      1       1.0
# 6633   Gary Johnson Equates Syria Deaths Caused by As...      1       0.0
# 6632   Gary Cohn Relaunches War on Coal: Fuel from Am...      1       0.0
# 6631   Garry Marshall, ‘Pretty Woman’ Director, Dies ...      1       0.0
# 6630   Garrison Keillor Turns Out the Lights on Lake ...      1       0.0
# 6629   Garlic: 12 Serious Health Benefits | Undergrou...      1       1.0
# 6628   Garlic Beats Drug In Detoxifying Lead Safely F...      1       1.0
# 6627   Gardaí Strike Negotiations Get Off To Bad Star...      1       1.0
# 6626        Gardasil is a Decision We Will Always Regret      1       1.0
# 19763  🚨Bill Clinton and Hillary Lolita Express Pedop...      1       1.0

# %%
title_stats[['total','fakeness']].value_counts()
# Out:
# total  fakeness
# 1      0.0         10377
#        1.0          9078
# 2      1.0           261
# 3      1.0            31
# 4      1.0            11
# 2      0.0             3
# 5      1.0             2
# 4      0.0             1
# Name: count, dtype: int64

# %% [markdown]
# * Majority of the titles are unique. The few that are duplicates are of records belonging to the same class, but the numbers aren't significant to allow the model to cheat. Hence, we will retain the titles and concatenate them to the text.

# %%
prepped_data.drop(columns='author', inplace=True)

# %%
prepped_data['full_text'] = prepped_data['title'].fillna("") + " " + prepped_data['text']

# %%
prepped_data.head()
# Out:
#                                                title  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                  Why the Truth Might Get You Fired
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                            full_text
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2  Why the Truth Might Get You Fired Why the Trut...
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...

# %% [markdown]
# ## Text Length Statistics

# %%
prepped_data['char_count'] = prepped_data['full_text'].astype(str).map(len)

# %%
prepped_data['char_count'].describe()
# Out:
# count     20652.000000
# mean       4628.469543
# std        5129.856542
# min           2.000000
# 25%        1712.750000
# 50%        3444.500000
# 75%        6359.000000
# max      143035.000000
# Name: char_count, dtype: float64

# %%
print("Shortest Text:")
print(prepped_data.loc[prepped_data['char_count'].idxmin(), ['text', 'char_count','label']])
# Out:
# Shortest Text:
# text          f
# char_count    2
# label         1
# Name: 786, dtype: object

# %%
print("Longest Text:")
print(prepped_data.loc[prepped_data['char_count'].idxmax(), ['text', 'char_count','label']])
# Out:
# Longest Text:
# text          Заседание Международного дискуссионного клуба ...
# char_count                                               143035
# label                                                         1
# Name: 19764, dtype: object

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# We will create new columns:
# 1. 'text_clean': lowercased, urls removed, contractions fixed, punctuations removed
# 2. 'tokens': list of lemmatized tokens after removing stopwords and non-english words
# 3. 'text_lemmatized': tokens joined back after lemmatization for TF-IDF
# 4. 'token_count'
#
#
# We will makes these for both text and full_text.

# %%
def fix_contractions_safe(s):
  try:
    return contractions.fix(s)
  except:
    return s
def clean_text(s):
    s = str(s)
    print(s[:10])
    # normalizing quotations
    quote_maps = {'“':'"', '”':'"', "‘":"'", "’":"'"}
    for curly_quote,quote in quote_maps.items():
        s = s.replace(curly_quote, quote)
    # remove non-ASCII
    s = re.sub(r'[^\x00-\x7F]+', ' ', s)
    # fixing contractions
    s = fix_contractions_safe(s)
    # removing urls
    s = re.sub(r'(https?:\/\/)?([\w\.-]+)\.([A-Za-z\.]{2,6})([\/\w \.-]*)*\/?', ' ', s)
    # removing punctuations (all non-alphanumeric characters and non-whitespaces)
    s = re.sub(r'[^a-zA-Z0-9 ]', ' ', s)
    # removing unnecessary whitespaces, newlines, tabspaces, etc.
    s = re.sub(r'\s+', ' ', s).strip()
    # returning lowercase text
    return s.lower()

# %%
prepped_data['text_clean'] = prepped_data['text'].progress_map(clean_text)

# %%
prepped_data['full_text_clean'] = prepped_data['full_text'].progress_map(clean_text)

# %%
display(prepped_data[['text','text_clean','full_text', 'full_text_clean']].head(10))
# Out:
#                                                 text  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  Ever get the feeling your life circles the rou...
# 2  Why the Truth Might Get You Fired October 29, ...
# 3  Videos 15 Civilians Killed In Single US Airstr...
# 4  Print \nAn Iranian woman has been sentenced to...
# 5  In these trying times, Jackie Mason is the Voi...
# 6  Ever wonder how Britain’s most iconic pop pian...
# 7  PARIS  —   France chose an idealistic, traditi...
# 8  Donald J. Trump is scheduled to make a highly ...
# 9  A week before Michael T. Flynn resigned as nat...
#
#                                           text_clean  \
# 0  house dem aide we did not even see comey s let...
# 1  ever get the feeling your life circles the rou...
# 2  why the truth might get you fired october 29 2...
# 3  videos 15 civilians killed in single us airstr...
# 4  print an iranian woman has been sentenced to s...
# 5  in these trying times jackie mason is the voic...
# 6  ever wonder how britain s most iconic pop pian...
# 7  paris france chose an idealistic traditional c...
# 8  donald j trump is scheduled to make a highly a...
# 9  a week before michael t flynn resigned as nati...
#
#                                            full_text  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2  Why the Truth Might Get You Fired Why the Trut...
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
# 5  Jackie Mason: Hollywood Would Love Trump if He...
# 6  Life: Life Of Luxury: Elton John’s 6 Favorite ...
# 7  Benoît Hamon Wins French Socialist Party’s Pre...
# 8  Excerpts From a Draft Script for Donald Trump’...
# 9  A Back-Channel Plan for Ukraine and Russia, Co...
#
#                                      full_text_clean
# 0  house dem aide we did not even see comey s let...
# 1  flynn hillary clinton big woman on campus brei...
# 2  why the truth might get you fired why the trut...
# 3  15 civilians killed in single us airstrike hav...
# 4  iranian woman jailed for fictional unpublished...
# 5  jackie mason hollywood would love trump if he ...
# 6  life life of luxury elton john s 6 favorite sh...
# 7  beno t hamon wins french socialist party s pre...
# 8  excerpts from a draft script for donald trump ...
# 9  a back channel plan for ukraine and russia cou...

# %%
def tokenize_and_lemmatize(s):
    print(s[:10])
    tokens = word_tokenize(s)
    tokens = [token for token in tokens 
              if token in ENGLISH_WORDS 
              and token not in STOP_WORDS
              and len(token)>2]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return tokens

# %%
prepped_data['tokens'] = prepped_data['text_clean'].progress_map(tokenize_and_lemmatize)

# %%
prepped_data['full_tokens'] = prepped_data['full_text_clean'].progress_map(tokenize_and_lemmatize)

# %%
prepped_data[['text', 'tokens', 'full_text', 'full_tokens']].head(10)
# Out:
#                                                 text  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  Ever get the feeling your life circles the rou...
# 2  Why the Truth Might Get You Fired October 29, ...
# 3  Videos 15 Civilians Killed In Single US Airstr...
# 4  Print \nAn Iranian woman has been sentenced to...
# 5  In these trying times, Jackie Mason is the Voi...
# 6  Ever wonder how Britain’s most iconic pop pian...
# 7  PARIS  —   France chose an idealistic, traditi...
# 8  Donald J. Trump is scheduled to make a highly ...
# 9  A week before Michael T. Flynn resigned as nat...
#
#                                               tokens  \
# 0  [house, aide, even, see, letter, jason, darrel...
# 1  [ever, get, feeling, life, roundabout, rather,...
# 2  [truth, might, get, fired, october, tension, i...
# 3  [single, rate, american, higher, engaged, acti...
# 4  [print, iranian, woman, six, prison, iran, rev...
# 5  [trying, time, mason, voice, reason, week, exc...
# 6  [ever, wonder, britain, iconic, pop, pianist, ...
# 7  [paris, chose, idealistic, traditional, candid...
# 8  [donald, trump, make, highly, visit, church, s...
# 9  [week, michael, resigned, national, security, ...
#
#                                            full_text  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2  Why the Truth Might Get You Fired Why the Trut...
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
# 5  Jackie Mason: Hollywood Would Love Trump if He...
# 6  Life: Life Of Luxury: Elton John’s 6 Favorite ...
# 7  Benoît Hamon Wins French Socialist Party’s Pre...
# 8  Excerpts From a Draft Script for Donald Trump’...
# 9  A Back-Channel Plan for Ukraine and Russia, Co...
#
#                                          full_tokens
# 0  [house, aide, even, see, letter, jason, house,...
# 1  [hillary, clinton, big, woman, campus, ever, g...
# 2  [truth, might, get, fired, truth, might, get, ...
# 3  [single, single, rate, american, higher, engag...
# 4  [iranian, woman, fictional, unpublished, story...
# 5  [mason, hollywood, would, love, trump, bombed,...
# 6  [life, life, luxury, john, favorite, shark, st...
# 7  [beno, french, socialist, party, presidential,...
# 8  [draft, script, donald, trump, black, church, ...
# 9  [back, channel, plan, russia, courtesy, trump,...

# %%
prepped_data['text_lemmatized'] = prepped_data['tokens'].map(lambda tokens: " ".join(tokens))

# %%
prepped_data['full_text_lemmatized'] = prepped_data['full_tokens'].map(lambda tokens: " ".join(tokens))

# %%
prepped_data['token_count'] = prepped_data['tokens'].map(len)

# %%
prepped_data['full_token_count'] = prepped_data['full_tokens'].map(len)

# %%
prepped_data.head()
# Out:
#                                                title  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                  Why the Truth Might Get You Fired
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                            full_text  char_count  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...        5012
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...        4216
# 2  Why the Truth Might Get You Fired Why the Trut...        7726
# 3  15 Civilians Killed In Single US Airstrike Hav...        3301
# 4  Iranian woman jailed for fictional unpublished...        1032
#
#                                           text_clean  \
# 0  house dem aide we did not even see comey s let...
# 1  ever get the feeling your life circles the rou...
# 2  why the truth might get you fired october 29 2...
# 3  videos 15 civilians killed in single us airstr...
# 4  print an iranian woman has been sentenced to s...
#
#                                      full_text_clean  \
# 0  house dem aide we did not even see comey s let...
# 1  flynn hillary clinton big woman on campus brei...
# 2  why the truth might get you fired why the trut...
# 3  15 civilians killed in single us airstrike hav...
# 4  iranian woman jailed for fictional unpublished...
#
#                                               tokens  \
# 0  [house, aide, even, see, letter, jason, darrel...
# 1  [ever, get, feeling, life, roundabout, rather,...
# 2  [truth, might, get, fired, october, tension, i...
# 3  [single, rate, american, higher, engaged, acti...
# 4  [print, iranian, woman, six, prison, iran, rev...
#
#                                          full_tokens  token_count  \
# 0  [house, aide, even, see, letter, jason, house,...          320
# 1  [hillary, clinton, big, woman, campus, ever, g...          287
# 2  [truth, might, get, fired, truth, might, get, ...          476
# 3  [single, single, rate, american, higher, engag...          192
# 4  [iranian, woman, fictional, unpublished, story...           62
#
#    full_token_count                                    text_lemmatized  \
# 0               326  house aide even see letter jason darrell octob...
# 1               292  ever get feeling life roundabout rather straig...
# 2               480  truth might get fired october tension intellig...
# 3               193  single rate american higher engaged active com...
# 4                71  print iranian woman six prison iran revolution...
#
#                                 full_text_lemmatized
# 0  house aide even see letter jason house aide ev...
# 1  hillary clinton big woman campus ever get feel...
# 2  truth might get fired truth might get fired oc...
# 3  single single rate american higher engaged act...
# 4  iranian woman fictional unpublished story woma...

# %% [markdown]
# ### Deleting Records with no valid tokens

# %%
prepped_data.describe()
# Out:
#               label     char_count   token_count  full_token_count
# count  20652.000000   20652.000000  20652.000000      20652.000000
# mean       0.497046    4628.469543    298.989057        304.664149
# std        0.500003    5129.856542    335.125542        335.515437
# min        0.000000       2.000000      0.000000          0.000000
# 25%        0.000000    1712.750000    106.000000        111.000000
# 50%        0.000000    3444.500000    220.000000        226.000000
# 75%        1.000000    6359.000000    415.000000        421.000000
# max        1.000000  143035.000000   9279.000000       9284.000000

# %%
prepped_data.loc[prepped_data['full_token_count']==0]
# Out:
#                                                    title  \
# 47     СМИ Сербии приписали россиянам "подготовку тер...
# 371    Путин рассказал, когда в Крыму решат проблему ...
# 492    Казахстан на страже ядерной безопасности | Нов...
# 580                                                  NaN
# 650    Очередная автоколонна МЧС с гуманитарной помощ...
# ...                                                  ...
# 18556  Минобороны России: Эвакуация жителей Алеппо бы...
# 19009  Опрос: Россияне одобряют действия президента П...
# 19734  Москва ввела в эксплуатацию систему по борьбе ...
# 20168  Стала известна возможная причина взрыва дома в...
# 20558                          Кто любит Стивена Сигала?
#
#                                                     text  label  \
# 47     0 комментариев 0 поделились Фото: AP \nОднако ...      1
# 371    0 комментариев 7 поделились \nОтвечая на соотв...      1
# 492    В ноябре 2016 г. Мажилис Парламента Республики...      1
# 580                                         Ludicrous...      1
# 650     19 МЧС направило 57-ю по счёту автоколонну с ...      1
# ...                                                  ...    ...
# 18556    \nКонашенков пояснил, что представителями си...      1
# 19009  0 комментариев 4 поделились Фото: AP \nКак пок...      1
# 19734    \nКак пишет Коммерсант, система под название...      1
# 20168  Фото: © Пресс-служба МЧС по Рязанской области ...      1
# 20558  Политика \nПомните первые видеосалоны 1990-х, ...      1
#
#                                                full_text  char_count  \
# 47     СМИ Сербии приписали россиянам "подготовку тер...        3651
# 371    Путин рассказал, когда в Крыму решат проблему ...        2013
# 492    Казахстан на страже ядерной безопасности | Нов...        6525
# 580                                         Ludicrous...          13
# 650    Очередная автоколонна МЧС с гуманитарной помощ...         757
# ...                                                  ...         ...
# 18556  Минобороны России: Эвакуация жителей Алеппо бы...        2188
# 19009  Опрос: Россияне одобряют действия президента П...        2768
# 19734  Москва ввела в эксплуатацию систему по борьбе ...        2801
# 20168  Стала известна возможная причина взрыва дома в...        2309
# 20558  Кто любит Стивена Сигала? Политика \nПомните п...        2756
#
#                                               text_clean  \
# 47         0 0 ap n1 26 27 16 16 20 viber whatsapp 27 27
# 371                       0 7 23 2015 2020 40 4 5 2 5 25
# 492    2016 2006 2011 2015 2015 2016 3 2016 2016 2018...
# 580
# 650                              19 57 40 440 2014 56 64
# ...                                                  ...
# 18556                       40 afp 2011 2011 220 2014 17
# 19009  0 4 ap 78 7 81 8 53 6 58 3 39 7 45 5 42 1 46 4...
# 19734  5 50 934 60 26 100 36 volkswagen 12 36 4 06 00...
# 20168                    23 10 1 279 61 162 31 pravda ru
# 20558                                            1990 90
#
#                                          full_text_clean tokens full_tokens  \
# 47         0 0 ap n1 26 27 16 16 20 viber whatsapp 27 27     []          []
# 371                       0 7 23 2015 2020 40 4 5 2 5 25     []          []
# 492    2016 2006 2011 2015 2015 2016 3 2016 2016 2018...     []          []
# 580                                                          []          []
# 650                              19 57 40 440 2014 56 64     []          []
# ...                                                  ...    ...         ...
# 18556                       40 afp 2011 2011 220 2014 17     []          []
# 19009  0 4 ap 78 7 81 8 53 6 58 3 39 7 45 5 42 1 46 4...     []          []
# 19734  5 50 934 60 26 100 36 volkswagen 12 36 4 06 00...     []          []
# 20168                    23 10 1 279 61 162 31 pravda ru     []          []
# 20558                                            1990 90     []          []
#
#        token_count  full_token_count text_lemmatized full_text_lemmatized
# 47               0                 0
# 371              0                 0
# 492              0                 0
# 580              0                 0
# 650              0                 0
# ...            ...               ...             ...                  ...
# 18556            0                 0
# 19009            0                 0
# 19734            0                 0
# 20168            0                 0
# 20558            0                 0
#
# [106 rows x 13 columns]

# %%
prepped_data = prepped_data.drop(index=prepped_data.loc[prepped_data['full_token_count']==0].index)
prepped_data.shape
# Out:
# (20546, 13)

# %%
prepped_data.describe()
# Out:
#               label     char_count   token_count  full_token_count
# count  20546.000000   20546.000000  20546.000000      20546.000000
# mean       0.494451    4639.159252    300.531588        306.235958
# std        0.499981    5138.287902    335.298338        335.663579
# min        0.000000       5.000000      0.000000          1.000000
# 25%        0.000000    1716.000000    107.000000        112.000000
# 50%        0.000000    3467.000000    222.000000        227.000000
# 75%        1.000000    6370.750000    416.000000        422.000000
# max        1.000000  143035.000000   9279.000000       9284.000000

# %%
prepped_data.to_csv('data/preprocessed_data.csv', index=False)

# %%
prepped_data = pd.read_csv('data/preprocessed_data.csv')

# %%
prepped_data[['full_text', 'full_tokens', 'full_text_lemmatized', 'label']].to_csv('data/fulltext_preprocessed_data.csv', index=False)

# %%
prepped_data2 = prepped_data[['text', 'tokens', 'text_lemmatized', 'label']]
prepped_data2 = prepped_data2.drop(index=prepped_data[prepped_data['token_count']==0].index)
prepped_data2.shape
# Out:
# (20459, 4)

# %%
prepped_data.to_csv('data/text_preprocessed_data.csv', index=False)
